# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import linear_model

# %%
kids={'Height':[65.75,71.52,69.40,71.22,67.79,71.70,69.80,70.01,67.90,66.78,66.49,67.62,68.30,67.12,68.28],
      'Weight':[112.99,136.49,123.03,132.34,124.30,148.30,141.49,136.46,122.37,120.67,127.45,124.14,125.61,122.46,116.09]}

# %%
dfkids=pd.DataFrame(kids)

# %%
print(dfkids)
# Out:
#     Height  Weight
# 0    65.75  112.99
# 1    71.52  136.49
# 2    69.40  123.03
# 3    71.22  132.34
# 4    67.79  124.30
# 5    71.70  148.30
# 6    69.80  141.49
# 7    70.01  136.46
# 8    67.90  122.37
# 9    66.78  120.67
# 10   66.49  127.45
# 11   67.62  124.14
# 12   68.30  125.61
# 13   67.12  122.46
# 14   68.28  116.09

# %%
dfkids.head()
# Out:
#    Height  Weight
# 0   65.75  112.99
# 1   71.52  136.49
# 2   69.40  123.03
# 3   71.22  132.34
# 4   67.79  124.30

# %%
dfkids.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Height  15 non-null     float64
#  1   Weight  15 non-null     float64
# dtypes: float64(2)
# memory usage: 368.0 bytes

# %%
dfkids.tail()
# Out:
#     Height  Weight
# 10   66.49  127.45
# 11   67.62  124.14
# 12   68.30  125.61
# 13   67.12  122.46
# 14   68.28  116.09

# %%
dfkids.describe()
# Out:
#           Height      Weight
# count  15.000000   15.000000
# mean   68.645333  127.612667
# std     1.878722    9.624662
# min    65.750000  112.990000
# 25%    67.370000  122.415000
# 50%    68.280000  124.300000
# 75%    69.905000  134.400000
# max    71.700000  148.300000

# %%
plt.xlabel('Height in inches')
plt.ylabel('Weight in pounds')
plt.scatter(dfkids.Height,dfkids.Weight,color='blue',marker='*')
plt.plot(dfkids.Height,reg.predict(dfkids[['Height']]),color='red')

# %%
reg.coef_
# Out:
# array([4.13287416])

# %%
reg.intercept_
# Out:
# -156.08985765005508

# %%
reg.predict([[71.20]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([138.17078252])
