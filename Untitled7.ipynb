# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
kids={'number':[1,2,3,4,5],
      'name':['mercy','sammy','chris','james','joseph']}

# %%
dfkids=pd.DataFrame(kids)

# %%
print(dfkids)
# Out:
#    number    name
# 0       1   mercy
# 1       2   sammy
# 2       3   chris
# 3       4   james
# 4       5  joseph

# %%
dfkids.head()
# Out:
#    number    name
# 0       1   mercy
# 1       2   sammy
# 2       3   chris
# 3       4   james
# 4       5  joseph

# %%
dfkids.describe()
# Out:
#          number
# count  5.000000
# mean   3.000000
# std    1.581139
# min    1.000000
# 25%    2.000000
# 50%    3.000000
# 75%    4.000000
# max    5.000000

# %%
plt.xlabel('name')
plt.ylabel('number')
plt.scatter(dfkids.name,dfkids.number,color='blue',marker='*')
plt.plot(dfkids.number,reg.predict(dfkids[['name']]),color='red')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-0cbd85f0dbe6> in <cell line: 4>()
#       2 plt.ylabel('number')
#       3 plt.scatter(dfkids.name,dfkids.number,color='blue',marker='*')
# ----> 4 plt.plot(dfkids.number,reg.predict(dfkids[['name']]),color='red')
#
# NameError: name 'reg' is not defined
