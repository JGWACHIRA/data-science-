# %%
import numpy
import pandas as pd
import matplotlib as npl

# %%
kids={'age':[1,2,3,4,5],
      'height':[21,22,23,24,25]}

# %%
dfk=pd.DataFrame(kids,index=['june','robert','lily','david','james',])

# %%
print(dfk)
# Out:
#         age  height
# june      1      21
# robert    2      22
# lily      3      23
# david     4      24
# james     5      25

# %%
dfk.age.mean()
# Out:
# 3.0

# %%
dfk.height.mean()
# Out:
# 23.0

# %%
dfk.corr()
# Out:
#         age  height
# age     1.0     1.0
# height  1.0     1.0

# %%
from matplotlib import pyplot as plt

# %%
x=dfk.age

# %%
y=dfk.height

# %%
plt.title("age height LINE PLOT")
# Out:
# Text(0.5, 1.0, 'age height LINE PLOT')

# %%
plt.xlabel("age")
# Out:
# Text(0.5, 0, 'age')

# %%
plt.ylabel("height")
# Out:
# Text(0, 0.5, 'height')

# %%
plt.plot(x,y,"-g")

# %%
plt.show()

# %%
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7a0d0b10b070>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7a0d0b108d60>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7a0d0b108880>],
#  'medians': [<matplotlib.lines.Line2D at 0x7a0d0b10a290>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7a0d0b10a830>],
#  'means': []}

# %%
plt.show()

# %%
plt.boxplot(y)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7a0d0b104910>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7a0d0b175150>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7a0d0b105c00>],
#  'medians': [<matplotlib.lines.Line2D at 0x7a0d0aaec3a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7a0d0aaec580>],
#  'means': []}

# %%
plt.show()
